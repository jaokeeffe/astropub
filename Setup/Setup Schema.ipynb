# %%
dbutils.widgets.dropdown('cat', 'astrodev', ['astrodev', 'astrobricks'])
dbutils.widgets.dropdown('db', 'images', ['images'])

# %%
# %sql
create table IDENTIFIER(:cat || '.' || :db || '.fits_files_raw') (imageid bigint generated by default as identity, path string, modificationTime timestamp, length bigint, content binary)

# %%
# %sql
create table IDENTIFIER(:cat || '.' || :db || '.fits_files_centroids') (imageid bigint generated by default as identity, centroidid bigint, xcentroid double, ycentroid double, sharpness double, roundness1 double, roundness2 double, npix bigint, peak double, flux double, mag double)
